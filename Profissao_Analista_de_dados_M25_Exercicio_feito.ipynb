# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Aprendizado de Máquina, Agrupamento
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Agrupamento;</li>
#   <li>Dados;</li>
#   <li>Treino;</li>
#   <li>Avaliação;</li>
#   <li>Predição.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Pinguins

# %% [markdown]
# Neste exercício, vamos utilizar uma base de dados com informações sobre flores do gênero iris. A idéia é agrupar as flores de acordo com suas características físicas (variáveis preditivas). Lembre-se das aulas, nós já temos uma idéia dos agrupamentos.

# %%
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris = iris.drop(['species'], axis=1)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# ### **1.1. Analise exploratoria**

# %% [markdown]
# Utilize os gráficos abaixo para entender melhor a relação entre os atributos da base de dados. Comente o que observou no gráfico.

# %% [markdown]
#  - Atributos preditivos:

# %%
with sns.axes_style('whitegrid'):

  grafico = sns.pairplot(data=iris, palette="pastel")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)

# %% [markdown]
# **Comentário:** ?

# %% [markdown]
# ## 2\. Dados

# %% [markdown]
# ### **2.1. Valores nulos**

# %% [markdown]
# Avalie se a base de dados possui valores faltantes, se sim, utilize os conceitos da aula para trata-los.

# %%
# resposta da questão 2.1
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %% [markdown]
# ### **2.2. Variáveis numéricas**

# %% [markdown]
# Identifique se existe a necessidade de escalar as variáveis numéricas. Se sim, crie uma nova coluna **padronizando** seus valores. A nova coluna deve ter o mesmo nome da coluna original acrescidade de "*_std*".

# %% [markdown]
# > **Nota**: Você não deve tratar a variável resposta.

# %%
# resposta da questão 2.2

# %% [markdown]
# ### **2.3. Limpeza**

# %% [markdown]
# Caso você tenha escalado suas variáveis, descarte as colunas originais e mantenha apenas as variáveis preditivas com o sufixo *_std*", *_nom*" e "*_ord*".

# %%
# resposta da questão 2.3

# %% [markdown]
# ## 3\. Modelagem

# %% [markdown]
# ### **3.1. Treino**

# %% [markdown]
# Treine 10 modelos de **k-médias** variando o número de clusters de 1 a 10. Para cada modelo treinado, salve o valor global do **wcss** em uma lista.

# %%
# resposta da questão 3.1
from sklearn.cluster import KMeans
model = KMeans(n_clusters=5)
model = model.fit(iris)

# %%
model.__dict__
# Out:
# {'n_clusters': 5,
#  'init': 'k-means++',
#  'max_iter': 300,
#  'tol': 0.0001,
#  'n_init': 'auto',
#  'verbose': 0,
#  'random_state': None,
#  'copy_x': True,
#  'algorithm': 'lloyd',
#  'feature_names_in_': array(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'],
#        dtype=object),
#  'n_features_in_': 4,
#  '_tol': 0.00011356176666666667,
#  '_n_init': 1,
#  '_algorithm': 'lloyd',
#  '_n_threads': 1,
#  'cluster_centers_': array([[6.9125    , 3.1       , 5.846875  , 2.13125   ],
#         [5.24285714, 3.66785714, 1.5       , 0.28214286],
#         [6.23658537, 2.85853659, 4.80731707, 1.62195122],
#         [5.52962963, 2.62222222, 3.94074074, 1.21851852],
#         [4.70454545, 3.12272727, 1.41363636, 0.2       ]]),
#  '_n_features_out': 5,
#  'labels_': array([1, 4, 4, 4, 1, 1, 4, 1, 4, 4, 1, 4, 4, 4, 1, 1, 1, 1, 1, 1, 1, 1,
#         4, 1, 4, 4, 1, 1, 1, 4, 4, 1, 1, 1, 4, 4, 1, 1, 4, 1, 1, 4, 4, 1,
#         1, 4, 1, 4, 1, 4, 2, 2, 2, 3, 2, 3, 2, 3, 2, 3, 3, 3, 3, 2, 3, 2,
#         2, 3, 2, 3, 2, 3, 2, 2, 2, 2, 2, 2, 2, 3, 3, 3, 3, 2, 3, 2, 2, 2,
#         3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 0, 2, 0, 0, 0, 0, 3, 0, 0, 0,
#         2, 2, 0, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 2, 0, 0, 2, 2, 0, 0, 0, 0,
#         0, 2, 2, 0, 0, 0, 2, 0, 0, 0, 2, 0, 0, 0, 2, 2, 0, 2], dtype=int32),
#  'inertia_': 49.84981451052334,
#  'n_iter_': 6}

# %%
clusters = model.labels_
clusters = pd.DataFrame(clusters, columns=['cluster'])
clusters.head()
# Out:
#    cluster
# 0        1
# 1        4
# 2        4
# 3        4
# 4        1

# %%
clustered_iris = pd.concat([iris, clusters], axis=1)
clustered_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  cluster
# 0           5.1          3.5           1.4          0.2        1
# 1           4.9          3.0           1.4          0.2        4
# 2           4.7          3.2           1.3          0.2        4
# 3           4.6          3.1           1.5          0.2        4
# 4           5.0          3.6           1.4          0.2        1

# %%
with sns.axes_style('whitegrid'):

  grafico = sns.pairplot(data=clustered_iris, hue='cluster', palette="pastel")

# %%
clusters_centers = model.cluster_centers_
clusters_centers = pd.DataFrame(clusters_centers, columns=['sepal_length',	'sepal_width',	'petal_length'	,'petal_width'])
clusters_centers.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0      6.912500     3.100000      5.846875     2.131250
# 1      5.242857     3.667857      1.500000     0.282143
# 2      6.236585     2.858537      4.807317     1.621951
# 3      5.529630     2.622222      3.940741     1.218519
# 4      4.704545     3.122727      1.413636     0.200000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
clustered_iris.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  cluster
# 0           5.1          3.5           1.4          0.2        1

# %%
with sns.axes_style('whitegrid'):

  fig, ax = plt.subplots()
  sns.scatterplot(data=clustered_iris,   x='sepal_width', y='petal_length', hue='cluster', palette="pastel", ax=ax)
  sns.scatterplot(data=clusters_centers, x='sepal_width', y='petal_length', color='black', ax=ax)

# %% [markdown]
# ### **3.2. Avaliação**

# %% [markdown]
# Gere um gráfico de linha dos valores do **wcss** pelo **número de clusters**. Utilize o método do cotovelo para decidir o número final de clusters.

# %%
wcss = []

for k in range(1, 11):

  model = KMeans(n_clusters=k)
  model = model.fit(iris)
  wcss.append(model.inertia_)

# %%
# resposta da questão 3.2
with sns.axes_style('whitegrid'):

  grafico = sns.lineplot(x=range(1, 11), y=wcss, marker="8", palette="pastel")
  grafico.set(title='Método do Cotovelo', ylabel='WCSS', xlabel='Qtd. clusters');
# Out:
# <ipython-input-30-a18915a6d5fc>:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   grafico = sns.lineplot(x=range(1, 11), y=wcss, marker="8", palette="pastel")

# %% [markdown]
# ### **3.3. Visualização**

# %%
# resposta da questão 3.3.a
model = KMeans(n_clusters=3)
model = model.fit(iris)

clusters = model.labels_
clustered_data = pd.concat([iris, pd.DataFrame(clusters, columns=['cluster'])], axis=1)

with sns.axes_style('whitegrid'):

  grafico = sns.pairplot(data=clustered_data, hue='cluster', palette="pastel")

  for ax in grafico.axes.flat:
    # Obter os nomes dos eixos atuais
    xlabel = ax.get_xlabel()
    ylabel = ax.get_ylabel()

    # Substituir os nomes dos eixos pelas traduções
    if xlabel == "sepal_length":
        ax.set_xlabel("Comprimento da Sépala")
    if xlabel == "sepal_width":
        ax.set_xlabel("Largura da Sépala")
    if xlabel == "petal_length":
        ax.set_xlabel("Comprimento da Pétala")
    if xlabel == "petal_width":
        ax.set_xlabel("Largura da Pétala")

    if ylabel == "sepal_length":
        ax.set_ylabel("Comprimento da Sépala")
    if ylabel == "sepal_width":
        ax.set_ylabel("Largura da Sépala")
    if ylabel == "petal_length":
        ax.set_ylabel("Comprimento da Pétala")
    if ylabel == "petal_width":
        ax.set_ylabel("Largura da Pétala")

plt.show()

# %% [markdown]
# **a)** Utilizando o número de clusters final, adicione uma coluna chamada **cluster** no dataframe **iris** com o número do cluster que cada flor foi alocada.

# %% [markdown]
# **b)** Gere a mesma visualização da sessão 1.1, agora passando como atributo **hue** a coluna **cluster**. Comente os resultados com base no valor esperado do número de clusters.

# %%
# resposta da questão 3.3.b

# %% [markdown]
# ## 4\. Predição

# %% [markdown]
# ### **4.1. Nova flor**

# %% [markdown]
# **Comentário:** optei por separar em 3 grupos, pois observei que há uma separação por tamanhos bem aparente dividida em pequeno intermediario e grande:
#
# **Cluster 0 :** tem o comprimento da sépala em sua maioria maior que os outros clusters, tem a largura da sépala intermediaria,tem o comprimento maior que os outros grupos o que coloca este grupo sendo de tamanho grande;
#
# **Cluster 1 :** ao meu ver  se encaixa em tamanho pequeno , pois com excessão do atributo de largura da sepala , que tem a maior largura dentre os 3 grupos, o resto dos atributos são menores que os outros grupos
#
# **Cluster 2 :** entra no grupo de tamanho intermediario , pois em quase todos atributos ele é maior que o cluster 1 e menor que o cluster 0

# %% [markdown]
# Em qual cluster a flor abaixo seria alocada?

# %% [markdown]
# | sepal_length	| sepal_width | petal_length | petal_width |
# | --- | --- | --- | --- |
# | 5.1 | 3.5 | 1.4 | 0.2 |

# %% [markdown]
# > **Atenção:** Lembre-se de pre-processar os atributos assim como nos exercício 2.2.

# %%
clustered_data[clustered_data["cluster"] == 0].describe().T
# Out:
#               count   mean       std  min  25%  50%    75%  max
# sepal_length   50.0  5.006  0.352490  4.3  4.8  5.0  5.200  5.8
# sepal_width    50.0  3.428  0.379064  2.3  3.2  3.4  3.675  4.4
# petal_length   50.0  1.462  0.173664  1.0  1.4  1.5  1.575  1.9
# petal_width    50.0  0.246  0.105386  0.1  0.2  0.2  0.300  0.6
# cluster        50.0  0.000  0.000000  0.0  0.0  0.0  0.000  0.0

# %%
# resposta da questão 4.1
clustered_data[clustered_data["cluster"] == 1].describe().T
# Out:
#               count      mean       std  min   25%  50%  75%  max
# sepal_length   39.0  6.853846  0.488201  6.1  6.45  6.7  7.2  7.9
# sepal_width    39.0  3.076923  0.286964  2.5  2.95  3.0  3.2  3.8
# petal_length   39.0  5.715385  0.510180  4.7  5.40  5.6  6.0  6.9
# petal_width    39.0  2.053846  0.296334  1.4  1.80  2.1  2.3  2.5
# cluster        39.0  1.000000  0.000000  1.0  1.00  1.0  1.0  1.0

# %%
clustered_data[clustered_data["cluster"] == 2].describe().T
# Out:
#               count      mean       std  min  25%  50%  75%  max
# sepal_length   61.0  5.883607  0.448025  4.9  5.6  5.9  6.2  6.8
# sepal_width    61.0  2.740984  0.292903  2.0  2.5  2.8  3.0  3.4
# petal_length   61.0  4.388525  0.511566  3.0  4.0  4.5  4.8  5.1
# petal_width    61.0  1.434426  0.299936  1.0  1.3  1.4  1.6  2.4
# cluster        61.0  2.000000  0.000000  2.0  2.0  2.0  2.0  2.0

# %%
flor = np.array([5.1, 3.5, 1.4, 0.2])
cluster = model.predict(flor.reshape(1, -1))
print(cluster)
# Out:
# [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ---

# %% [markdown]
# **comentarios:** essa nova flor entrou no cluster 1, que é o grupo das menores , com quase todos atributos pequenos e com a largura da sepala grande
